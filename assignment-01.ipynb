# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/sleep-deprivation-and-cognitive-performance/sleep_deprivation_dataset_detailed.csv

# %%
df=pd.read_csv("/kaggle/input/sleep-deprivation-and-cognitive-performance/sleep_deprivation_dataset_detailed.csv")
print(df)
# Out:
#    Participant_ID  Sleep_Hours  Sleep_Quality_Score  Daytime_Sleepiness  \
# 0              P1         5.25                   15                  12
# 1              P2         8.70                   12                  14
# 2              P3         7.39                   17                  10
# 3              P4         6.59                   14                   3
# 4              P5         3.94                   20                  12
# 5              P6         3.94                   12                   6
# 6              P7         3.35                    8                  18
# 7              P8         8.20                   14                  21
# 8              P9         6.61                   12                   1
# 9             P10         7.25                    0                   9
# 10            P11         3.12                    6                  12
# 11            P12         8.82                    8                  24
# 12            P13         7.99                    0                  20
# 13            P14         4.27                   11                   5
# 14            P15         4.09                    7                  11
# 15            P16         4.10                   10                  11
# 16            P17         4.83                   18                  19
# 17            P18         6.15                   16                  10
# 18            P19         5.59                    7                  22
# 19            P20         4.75                    2                  24
# 20            P21         6.67                    2                   6
# 21            P22         3.84                    0                   0
# 22            P23         4.75                    4                   0
# 23            P24         5.20                    9                  24
# 24            P25         5.74                    6                  24
# 25            P26         7.71                    8                  19
# 26            P27         4.20                    6                  12
# 27            P28         6.09                    8                   8
# 28            P29         6.55                    7                   2
# 29            P30         3.28                   11                   6
# 30            P31         6.65                    1                   5
# 31            P32         4.02                    0                   7
# 32            P33         3.39                   15                   8
# 33            P34         8.69                    4                   4
# 34            P35         8.79                    2                   0
# 35            P36         7.85                   11                  18
# 36            P37         4.83                    7                   9
# 37            P38         3.59                    2                  11
# 38            P39         7.11                    0                  23
# 39            P40         5.64                    2                  14
# 40            P41         3.73                    4                  21
# 41            P42         5.97                   14                  23
# 42            P43         3.21                   13                   8
# 43            P44         8.46                    2                  19
# 44            P45         4.55                    0                  16
# 45            P46         6.98                    4                  16
# 46            P47         4.87                   13                  19
# 47            P48         6.12                    6                  11
# 48            P49         6.28                    8                   6
# 49            P50         4.11                   14                   1
# 50            P51         8.82                   14                   2
# 51            P52         7.65                    9                  16
# 52            P53         8.64                   12                   4
# 53            P54         8.37                   18                  16
# 54            P55         6.59                    6                  23
# 55            P56         8.53                   16                  16
# 56            P57         3.53                   19                  16
# 57            P58         4.18                    3                   1
# 58            P59         3.27                    4                   1
# 59            P60         4.95                    6                  21
#
#     Stroop_Task_Reaction_Time  N_Back_Accuracy  Emotion_Regulation_Score  \
# 0                        1.60            64.20                        12
# 1                        2.54            65.27                        21
# 2                        3.40            74.28                        35
# 3                        3.54            72.42                        25
# 4                        3.09            99.72                        60
# 5                        2.84            58.80                        46
# 6                        3.16            50.90                        31
# 7                        3.28            74.69                        66
# 8                        1.74            58.94                        38
# 9                        2.61            68.32                        23
# 10                       2.23            87.21                        37
# 11                       3.91            86.05                        14
# 12                       2.91            65.40                        56
# 13                       4.45            77.13                        58
# 14                       2.70            75.44                        39
# 15                       3.95            81.82                        55
# 16                       3.90            62.52                        61
# 17                       1.95            79.49                        14
# 18                       3.02            98.94                        21
# 19                       3.59            74.34                        25
# 20                       4.08            95.30                        35
# 21                       2.48            71.72                        35
# 22                       2.16            67.50                        57
# 23                       3.63            82.26                        30
# 24                       3.93            83.45                        48
# 25                       2.55            93.21                        45
# 26                       1.79            61.51                        42
# 27                       4.32            74.96                        39
# 28                       2.69            78.60                        46
# 29                       3.05            88.43                        32
# 30                       4.01            52.18                        67
# 6                         5            16
# 7                         0             4
# 8                         4            28
# 9                         4             3
# 10                        5             9
# 11                        2            16
# 12                        4             9
# 13                        6            16
# 14                        4            19
# 15                        4            23
# 16                        4             4
# 17                        9            33
# 18                        9             5
# 19                        2             1
# 20                        0            12
# 21                        4            10
# 22                        8            22
# 23                        0            15
# 24                        2            30
# 25                        3            10
# 26                        0            15
# 27                        0             7
# 28                        7             3
# 29                        1            39
# 30                        7             3
# 31                        6            24
# 32                        9             2
# 33                        9            31
# 34                        1             2
# 35                        5            26
# 36                        5            28
# 37                        2            31
# 38                       10            18
# 39                        1            20
# 40                        0             4
# 41                        5            17
# 42                        4            27
# 43                       10            21
# 44                        8            20
# 45                        0             5
# 46                        6             0
# 47                        4             4
# 48                        4            40
# 49                        1            11
# 50                       10            25
# 51                        2            33
# 52                        6            13
# 53                        5            25
# 54                        1            26
# 55                        5             8
# 56                        1            25
# 57                        1            21
# 58                        1            29
# 59                       10            16

# %%
df.head()
# Out:
#   Participant_ID  Sleep_Hours  Sleep_Quality_Score  Daytime_Sleepiness  \
# 0             P1         5.25                   15                  12
# 1             P2         8.70                   12                  14
# 2             P3         7.39                   17                  10
# 3             P4         6.59                   14                   3
# 4             P5         3.94                   20                  12
#
#    Stroop_Task_Reaction_Time  N_Back_Accuracy  Emotion_Regulation_Score  \
# 0                       1.60            64.20                        12
# 1                       2.54            65.27                        21
# 2                       3.40            74.28                        35
# 3                       3.54            72.42                        25
# 4                       3.09            99.72                        60
#
#    PVT_Reaction_Time  Age  Gender    BMI  Caffeine_Intake  \
# 0             365.85   35  Female  30.53                2
# 1             288.95   20    Male  27.28                3
# 2             325.93   18    Male  30.00                1
# 3             276.86   18    Male  34.47                5
# 4             383.45   36    Male  29.70                3
#
#    Physical_Activity_Level  Stress_Level
# 0                        1            33
# 1                        8            37
# 2                        2            32
# 3                        0            23
# 4                        4            14

# %%
df.tail()
# Out:
#    Participant_ID  Sleep_Hours  Sleep_Quality_Score  Daytime_Sleepiness  \
# 55            P56         8.53                   16                  16
# 56            P57         3.53                   19                  16
# 57            P58         4.18                    3                   1
# 58            P59         3.27                    4                   1
# 59            P60         4.95                    6                  21
#
#     Stroop_Task_Reaction_Time  N_Back_Accuracy  Emotion_Regulation_Score  \
# 55                       3.51            64.76                        41
# 56                       3.24            66.13                        36
# 57                       2.62            92.43                        29
# 58                       4.32            56.83                        33
# 59                       4.42            85.45                        21
#
#     PVT_Reaction_Time  Age  Gender    BMI  Caffeine_Intake  \
# 55             391.48   34    Male  23.01                2
# 56             355.01   24  Female  34.93                2
# 57             397.13   41    Male  29.85                0
# 58             330.70   40  Female  24.53                4
# 59             419.01   22    Male  30.53                0
#
#     Physical_Activity_Level  Stress_Level
# 55                        5             8
# 56                        1            25
# 57                        1            21
# 58                        1            29
# 59                       10            16

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %%
#importing important liabraries
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# UNIVARIATE DATA ANALYSIS

# %%
#defining a univaraite function for performing anaylsis of every column
def ua(column):
    print(f"\nUnivariate Analysis for {column}:")
    print(df[column].describe())  # Descriptive statistics
    
    plt.figure(figsize=(12, 6))
    
    # Check if the column is numerical or categorical
    if df[column].dtype != 'object':  # Numerical column
        # Histogram
        plt.subplot(1, 2, 1)
        sns.histplot(df[column], kde=True, color='blue', bins=20)
        plt.title(f'Histogram of {column}')
        plt.xlabel(column)
        plt.ylabel('Frequency')
        
        # Box Plot
        plt.subplot(1, 2, 2)
        sns.boxplot(x=df[column], color='orange')
        plt.title(f'Box Plot of {column}')
    
    else:  # Categorical column
        # Bar Plot
        sns.countplot(x=df[column], palette='viridis')
        plt.title(f'Bar Plot of {column}')
        plt.xlabel(column)
        plt.ylabel('Count')
    
    plt.tight_layout()
    plt.show()

# Perform univariate analysis for all columns
for column in df.columns:
    ua(column)
# Out:
# Univariate Analysis for Participant_ID:
# count     60
# unique    60
# top       P1
# freq       1
# Name: Participant_ID, dtype: object
# Univariate Analysis for Sleep_Hours:
# count    60.000000
# mean      5.805500
# std       1.832357
# min       3.120000
# 25%       4.107500
# 50%       5.690000
# 75%       7.285000
# max       8.820000
# Name: Sleep_Hours, dtype: float64
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Univariate Analysis for Sleep_Quality_Score:
# count    60.000000
# mean      8.316667
# std       5.637320
# min       0.000000
# 25%       4.000000
# 50%       8.000000
# 75%      13.000000
# max      20.000000
# Name: Sleep_Quality_Score, dtype: float64
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Univariate Analysis for Daytime_Sleepiness:
# count    60.000000
# mean     12.000000
# std       7.577845
# min       0.000000
# 25%       6.000000
# 50%      11.500000
# 75%      19.000000
# max      24.000000
# Name: Daytime_Sleepiness, dtype: float64
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Univariate Analysis for Stroop_Task_Reaction_Time:
# count    60.000000
# mean      3.245000
# std       0.827368
# min       1.600000
# 25%       2.595000
# 50%       3.260000
# 75%       3.965000
# max       4.490000
# Name: Stroop_Task_Reaction_Time, dtype: float64
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Univariate Analysis for N_Back_Accuracy:
# count    60.000000
# mean     75.005833
# std      13.671457
# min      50.900000
# 25%      64.620000
# 50%      74.270000
# 75%      85.600000
# max      99.730000
# Name: N_Back_Accuracy, dtype: float64
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Univariate Analysis for Emotion_Regulation_Score:
# count    60.0000
# mean     38.1500
# std      17.1334
# min      10.0000
# 25%      25.0000
# 50%      37.0000
# 75%      54.2500
# max      67.0000
# Name: Emotion_Regulation_Score, dtype: float64
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Univariate Analysis for PVT_Reaction_Time:
# count     60.000000
# mean     332.539000
# std       87.800288
# min      201.560000
# 25%      257.535000
# 50%      327.210000
# 75%      402.845000
# max      494.550000
# Name: PVT_Reaction_Time, dtype: float64
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Univariate Analysis for Age:
# count    60.000000
# mean     29.516667
# std       8.168753
# min      18.000000
# 25%      21.750000
# 50%      28.500000
# 75%      36.000000
# max      43.000000
# Name: Age, dtype: float64
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Univariate Analysis for Gender:
# count       60
# unique       2
# top       Male
# freq        37
# Name: Gender, dtype: object
# Univariate Analysis for BMI:
# count    60.000000
# mean     27.329333
# std       4.541382
# min      18.740000
# 25%      23.580000
# 50%      27.365000
# 75%      30.747500
# max      34.930000
# Name: BMI, dtype: float64
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Univariate Analysis for Caffeine_Intake:
# count    60.000000
# mean      2.383333
# std       1.688362
# min       0.000000
# 25%       1.000000
# 50%       2.500000
# 75%       4.000000
# max       5.000000
# Name: Caffeine_Intake, dtype: float64
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Univariate Analysis for Physical_Activity_Level:
# count    60.000000
# mean      4.116667
# std       3.108717
# min       0.000000
# 25%       1.000000
# 50%       4.000000
# 75%       6.000000
# max      10.000000
# Name: Physical_Activity_Level, dtype: float64
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Univariate Analysis for Stress_Level:
# count    60.000000
# mean     17.866667
# std      11.015346
# min       0.000000
# 25%       8.750000
# 50%      17.500000
# 75%      26.250000
# max      40.000000
# Name: Stress_Level, dtype: float64
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
